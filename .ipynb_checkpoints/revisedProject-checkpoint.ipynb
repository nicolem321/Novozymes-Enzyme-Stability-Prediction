# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import spearmanr
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
from sklearn.model_selection import GridSearchCV

# %%
df_train = pd.read_csv("train.csv")
df_updated = pd.read_csv("train_updates.csv")
df_test =  pd.read_csv("test.csv")
for seq_id in df_updated.seq_id:
    df_train = df_train.drop(index = seq_id)

# %%
df_train.describe().T.style.background_gradient("YlOrRd")
# Out:
# <style type="text/css">
# #T_9fc3a_row0_col0, #T_9fc3a_row0_col1, #T_9fc3a_row0_col2, #T_9fc3a_row0_col4, #T_9fc3a_row0_col5, #T_9fc3a_row0_col6, #T_9fc3a_row0_col7, #T_9fc3a_row2_col0, #T_9fc3a_row2_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_9fc3a_row0_col3, #T_9fc3a_row1_col0, #T_9fc3a_row1_col1, #T_9fc3a_row1_col2, #T_9fc3a_row1_col4, #T_9fc3a_row1_col5, #T_9fc3a_row1_col6, #T_9fc3a_row1_col7, #T_9fc3a_row2_col1, #T_9fc3a_row2_col2, #T_9fc3a_row2_col5, #T_9fc3a_row2_col6, #T_9fc3a_row2_col7 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_9fc3a_row1_col3 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_9fc3a_row2_col4 {
#   background-color: #fffecb;
#   color: #000000;
# }
# </style>
# <table id="T_9fc3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fc3a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_9fc3a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_9fc3a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_9fc3a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_9fc3a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_9fc3a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_9fc3a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_9fc3a_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fc3a_level0_row0" class="row_heading level0 row0" >seq_id</th>
#       <td id="T_9fc3a_row0_col0" class="data row0 col0" >28956.000000</td>
#       <td id="T_9fc3a_row0_col1" class="data row0 col1" >15744.916529</td>
#       <td id="T_9fc3a_row0_col2" class="data row0 col2" >9251.179714</td>
#       <td id="T_9fc3a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_9fc3a_row0_col4" class="data row0 col4" >7526.750000</td>
#       <td id="T_9fc3a_row0_col5" class="data row0 col5" >15587.500000</td>
#       <td id="T_9fc3a_row0_col6" class="data row0 col6" >23902.250000</td>
#       <td id="T_9fc3a_row0_col7" class="data row0 col7" >31389.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9fc3a_level0_row1" class="row_heading level0 row1" >pH</th>
#       <td id="T_9fc3a_row1_col0" class="data row1 col0" >28670.000000</td>
#       <td id="T_9fc3a_row1_col1" class="data row1 col1" >6.872918</td>
#       <td id="T_9fc3a_row1_col2" class="data row1 col2" >0.792550</td>
#       <td id="T_9fc3a_row1_col3" class="data row1 col3" >1.990000</td>
#       <td id="T_9fc3a_row1_col4" class="data row1 col4" >7.000000</td>
#       <td id="T_9fc3a_row1_col5" class="data row1 col5" >7.000000</td>
#       <td id="T_9fc3a_row1_col6" class="data row1 col6" >7.000000</td>
#       <td id="T_9fc3a_row1_col7" class="data row1 col7" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9fc3a_level0_row2" class="row_heading level0 row2" >tm</th>
#       <td id="T_9fc3a_row2_col0" class="data row2 col0" >28956.000000</td>
#       <td id="T_9fc3a_row2_col1" class="data row2 col1" >51.360399</td>
#       <td id="T_9fc3a_row2_col2" class="data row2 col2" >12.060858</td>
#       <td id="T_9fc3a_row2_col3" class="data row2 col3" >25.100000</td>
#       <td id="T_9fc3a_row2_col4" class="data row2 col4" >43.600000</td>
#       <td id="T_9fc3a_row2_col5" class="data row2 col5" >48.800000</td>
#       <td id="T_9fc3a_row2_col6" class="data row2 col6" >54.600000</td>
#       <td id="T_9fc3a_row2_col7" class="data row2 col7" >130.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
lengths = []
for i in range (len(df_train)):
    lengths.append(len(df_train["protein_sequence"].iloc[i]))
df_train["length"] = lengths

# %%
test_lengths = []
for i in range (len(df_test)):
    test_lengths.append(len(df_test["protein_sequence"].iloc[i]))
df_test["length"] = test_lengths

# %%
amino_acids= ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']
for letter in amino_acids:
    df_train[letter] = df_train.protein_sequence.str.count(letter)
    df_test[letter] = df_test.protein_sequence.str.count(letter)

# %%
df_train = df_train[df_train["tm"] > 60]

from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Iterate over column names
for column in df_train:
    if df_train[column].dtype.kind == 'O':
        df_train[column]= label_encoder.fit_transform(df_train[column])
        df_test[column]= label_encoder.fit_transform(df_test[column])

# %%
# fitting our model
X = df_train.drop(columns=["protein_sequence","tm"])
y = df_train["tm"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#        seq_id   pH  data_source  length   A   C   D   E   F   G  ...   M   N  \
# 29266   29266  7.0          176     202  13   0  11   7   9  16  ...   4  15
# 19496   19496  8.0           70     455  45   5  15  32  21  46  ...  13  13
# 19783   19783  7.0          176     278  19   3  15   8  15  20  ...   8  25
# 489       489  7.0          176     715  70  13  34  43  35  46  ...  11  25
# 14884   14884  7.0          176     305  24   3  15  24  12  30  ...   8  13
# ...       ...  ...          ...     ...  ..  ..  ..  ..  ..  ..  ...  ..  ..
# 22559   22559  7.0          176     180   9   0  13  12   5  11  ...   5   8
# 412       412  7.0          176     445  32   3  27  44  13  32  ...  10  20
# 11244   11244  7.0          176     298  16   1  15  25  10  27  ...   2  15
# 21163   21163  7.0          176     141  15   0  11   8   4  16  ...   4   0
# 1564     1564  7.0          176    1415  93  18  76  99  54  88  ...  34  59
#
#         P   Q   R    S   T   V   W   Y
# 29266   7   2  17   15  10  13   1  17
# 19496  24  25  19   25  16  30   4  14
# 19783   7   5  11   27  11  10   0  14
# 489    49  32  45   56  33  48  14  18
# 14884  16   6  18   10  19  23   0  10
# ...    ..  ..  ..  ...  ..  ..  ..  ..
# 22559   8   5  14   16   9  15   1   5
# 412    22  15  22   19  21  29   4  17
# 11244  12   5  17   11  17  36   1  16
# 21163   6   6  12    5   4  13   1   2
# 1564   89  59  72  135  93  93  20  47
#
# [3928 rows x 24 columns]

# %%
y_train
# Out:
# 29266    67.1
# 19496    68.0
# 19783    68.8
# 489      61.6
# 14884    69.1
#          ...
# 22559    83.3
# 412      73.0
# 11244    74.9
# 21163    87.8
# 1564     62.4
# Name: tm, Length: 3928, dtype: float64

# %% [markdown]
# # Model 1: XGBRegressor

# %%
model = XGBRegressor().fit(X_train,y_train)
prediction1 = model.predict(X_test)
corr, p = spearmanr(y_test,prediction1)
print("Spearman Correlation: ",corr)
# Out:
# Spearman Correlation:  0.7675805207184684

# %% [markdown]
# # Model 2: XGBRegressor with tuning

# %%
model = XGBRegressor()
params = {"n_estimators":[100,200,300],"max_depth":[3,5,7],"learning_rate":[0.1,0.05,0.001]}
tuned_model = GridSearchCV(model,param_grid=params,cv=5,verbose=2,n_jobs=-1).fit(X_train,y_train)
tuned_model.best_params_
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300}

# %%
model2 = XGBRegressor(n_estimators=300,learning_rate=0.05,max_depth=7).fit(X_train,y_train)
prediction2 = model2.predict(X_test)
corr, p = spearmanr(y_test,prediction2)
print("Spearman Correlation with Tuned Parameters: ",corr)
# Out:
# Spearman Correlation with Tuned Parameters:  0.7936095253908795

# %% [markdown]
# # Model 3: Previous XGBRegressor with RandomizeSearchCV

# %%
previous_model = XGBRegressor(subsample=0.6,
                         n_estimators=500,
                         max_depth=6,
                         learning_rate=0.01,
                         colsample_bytree=0.7999999999999999,
                         colsample_bylevel=0.5,
                         seed=20).fit(X_train, y_train)
prediction3 = previous_model.predict(X_test)
corr, p = spearmanr(y_test,prediction3)
print("Spearman Correlation: ",corr)
# Out:
# Spearman Correlation:  0.7901612391445052

# %% [markdown]
# # Generating Final Predictions

# %%
df_test = df_test.drop(columns=["protein_sequence"])
submission = pd.read_csv("sample_submission.csv")

# %%
submission_prediction1 = model.predict(df_test)
submission_prediction2 = model2.predict(df_test)
submission_prediction3 =  previous_model.predict(df_test)

# %%
submission["tm"] = submission_prediction1
submission.to_csv('prediction1.csv', index = False)

# %%
submission["tm"] = submission_prediction2
submission.to_csv('prediction2.csv', index = False)

# %%
submission["tm"] = submission_prediction3
submission.to_csv('prediction3.csv', index = False)
# Out:
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=200; total time=   2.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=300; total time=   3.7s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   2.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   2.9s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   2.4s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=200; total time=   3.5s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=300; total time=   3.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.9s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=200; total time=   2.9s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=300; total time=   3.6s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   1.5s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=200; total time=   2.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=200; total time=   3.0s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=300; total time=   3.7s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   1.4s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=300; total time=   3.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=200; total time=   3.0s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   2.4s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=200; total time=   3.5s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   2.0s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=200; total time=   2.0s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   2.0s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=300; total time=   3.7s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   1.4s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=300; total time=   3.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   2.9s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   2.3s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=200; total time=   3.5s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=300; total time=   3.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   4.7s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   1.8s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=300; total time=   5.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=100; total time=   1.0s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=200; total time=   1.9s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=200; total time=   3.0s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   2.4s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=300; total time=   5.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=100; total time=   1.0s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=200; total time=   1.9s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   2.9s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   1.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   1.5s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   1.0s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   2.0s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=200; total time=   1.9s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   4.6s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   1.8s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=300; total time=   5.1s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=300; total time=   3.0s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   2.9s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   1.9s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   2.4s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=200; total time=   3.5s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=100; total time=   1.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=300; total time=   2.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   4.7s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   1.8s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=300; total time=   5.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=100; total time=   1.2s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=300; total time=   2.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   4.6s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=300; total time=   3.9s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=300; total time=   2.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   4.7s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=200; total time=   3.5s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   1.4s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.9s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=300; total time=   2.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   2.9s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   2.1s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   1.8s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=300; total time=   5.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=100; total time=   1.1s
# [CV] END .learning_rate=0.001, max_depth=7, n_estimators=300; total time=   2.5s
